# %% [markdown]
# <img src="https://gallery.mailchimp.com/f98d5ac0a3fbbdcdda35136ab/images/370b1236-88aa-4969-b768-cd07bd006d8c.png">

# %% [markdown]
# # Finance APIs (Open APIs)
#
# <img src='../assets/financialmodelprep-logo1.png' style='width:300px'>
#
# The APIs that we have interacted thus far have provided us with ways to utilise pretrained AI models and solutions. However, those APIs do not necessarily serve the purpose of providing us with data relevant for our own use cases. This is where we tap on to open data repositories or APIs that can provide us with useful information.
#
# For today's context let us tap on to an API that can provide us with financial data: [Financial Modeling Prep](https://financialmodelingprep.com). We can retrieve data from their API through URL endpoints as stated on their [API documentation](https://financialmodelingprep.com/developer/docs). For us to interact with such URL endpoints, we have to use the [`urllib`](https://docs.python.org/3/library/urllib.html) library.
#
# What we are going to do in this exercise is to retrieve the data from the APIs in JSON format, parse it, and store it in `pandas` dataframes.

# %%
from urllib.request import urlopen
import json

# %% [markdown]
# First, let us assign to a variable a URL endpoint. You can select any URL endpoint with JSON as the specified data type. For this first example, let us go with an endpoint that gives us data in regards to cryptocurrencies.

# %%
crypto_url = 'https://financialmodelingprep.com/api/cryptocurrency?datatype=json'

# %% [markdown]
# Now, using the `urlopen` function, we interact with the API endpoint and have `json` to parse the data.

# %%
crypto_response = urlopen(crypto_url)
crypto_data = crypto_response.read().decode("utf-8")
crypto_data
# Out:
# '{\n    "BTC": {\n        "Ticker": "BTC",\n        "Price": 7154.05,\n        "Changes": 5.45,\n        "name": "Bitcoin",\n        "market_cap_usd": 126597000000\n    },\n    "ETH": {\n        "Ticker": "ETH",\n        "Price": 189.619,\n        "Changes": 0.2,\n        "name": "Ethereum",\n        "market_cap_usd": 20106500000\n    },\n    "XRP": {\n        "Ticker": "XRP",\n        "Price": 0.312575,\n        "Changes": -0.24,\n        "name": "Ripple",\n        "market_cap_usd": 13169800000\n    },\n    "BCH": {\n        "Ticker": "BCH",\n        "Price": 353.042,\n        "Changes": 10.14,\n        "name": "Bitcoin Cash",\n        "market_cap_usd": 6276350000\n    },\n    "EOS": {\n        "Ticker": "EOS",\n        "Price": 5.41698,\n        "Changes": 1.86,\n        "name": "EOS",\n        "market_cap_usd": 4936450000\n    },\n    "LTC": {\n        "Ticker": "LTC",\n        "Price": 87.638,\n        "Changes": 1.6,\n        "name": "Litecoin",\n        "market_cap_usd": 5410550000\n    },\n    "ADA": {\n        "Ticker": "ADA",\n        "Price": 0.0708406,\n        "Changes": 0.06,\n        "name": "Cardano",\n        "market_cap_usd": 1836690000\n    },\n    "XLM": {\n        "Ticker": "XLM",\n        "Price": 0.099908,\n        "Changes": 1.77,\n        "name": "Stellar",\n        "market_cap_usd": 1916700000\n    },\n    "MIOTA": {\n        "Ticker": "MIOTA",\n        "Price": 0.301348,\n        "Changes": -0.01,\n        "name": "IOTA",\n        "market_cap_usd": 837606000\n    },\n    "TRX": {\n        "Ticker": "TRX",\n        "Price": 0.0241723,\n        "Changes": -2.25,\n        "name": "TRON",\n        "market_cap_usd": 1611860000\n    },\n    "NEO": {\n        "Ticker": "NEO",\n        "Price": 9.47268,\n        "Changes": -1.11,\n        "name": "NEO",\n        "market_cap_usd": 615724000\n    },\n    "DASH": {\n        "Ticker": "DASH",\n        "Price": 121.718,\n        "Changes": 2,\n        "name": "Dash",\n        "market_cap_usd": 1071480000\n    },\n    "XMR": {\n        "Ticker": "XMR",\n        "Price": 74.8016,\n        "Changes": 2.69,\n        "name": "Monero",\n        "market_cap_usd": 1269830000\n    },\n    "XEM": {\n        "Ticker": "XEM",\n        "Price": 0.0565246,\n        "Changes": -0.22,\n        "name": "NEM",\n        "market_cap_usd": 508722000\n    },\n    "VEN": {\n        "Ticker": "VEN",\n        "Price": 1.73492,\n        "Changes": -13.36,\n        "name": "VeChain",\n        "market_cap_usd": 962093000\n    },\n    "ETC": {\n        "Ticker": "ETC",\n        "Price": 5.89601,\n        "Changes": -0.31,\n        "name": "Ethereum Classic",\n        "market_cap_usd": 650903000\n    },\n    "USDT": {\n        "Ticker": "USDT",\n        "Price": 1.00038,\n        "Changes": -0.35,\n        "name": "Tether",\n        "market_cap_usd": 2779160000\n    },\n    "QTUM": {\n        "Ticker": "QTUM",\n        "Price": 2.45568,\n        "Changes": -1.96,\n        "name": "Qtum",\n        "market_cap_usd": 235043000\n    },\n    "OMG": {\n        "Ticker": "OMG",\n        "Price": 1.69212,\n        "Changes": -2.73,\n        "name": "OmiseGO",\n        "market_cap_usd": 237312000\n    },\n    "ICX": {\n        "Ticker": "ICX",\n        "Price": 0.329284,\n        "Changes": -3.03,\n        "name": "ICON",\n        "market_cap_usd": 155885000\n    },\n    "BNB": {\n        "Ticker": "BNB",\n        "Price": 20.8867,\n        "Changes": 2.16,\n        "name": "Binance Coin",\n        "market_cap_usd": 2948680000\n    },\n    "LSK": {\n        "Ticker": "LSK",\n        "Price": 1.9057,\n        "Changes": 0.05,\n        "name": "Lisk",\n        "market_cap_usd": 222705000\n    },\n    "BTG": {\n        "Ticker": "BTG",\n        "Price": 22.1799,\n        "Changes": 5.64,\n        "name": "Bitcoin Gold",\n        "market_cap_usd": 388457000\n    },\n    "NANO": {\n        "Ticker": "NANO",\n        "Price": 1.674,\n        "Changes": 5.03,\n        "name": "Nano",\n        "market_cap_usd" ...

# %%
crypto_data_parsed = json.loads(crypto_data)
crypto_data_parsed
# Out:
# {'BTC': {'Ticker': 'BTC',
#   'Price': 7154.05,
#   'Changes': 5.45,
#   'name': 'Bitcoin',
#   'market_cap_usd': 126597000000},
#  'ETH': {'Ticker': 'ETH',
#   'Price': 189.619,
#   'Changes': 0.2,
#   'name': 'Ethereum',
#   'market_cap_usd': 20106500000},
#  'XRP': {'Ticker': 'XRP',
#   'Price': 0.312575,
#   'Changes': -0.24,
#   'name': 'Ripple',
#   'market_cap_usd': 13169800000},
#  'BCH': {'Ticker': 'BCH',
#   'Price': 353.042,
#   'Changes': 10.14,
#   'name': 'Bitcoin Cash',
#   'market_cap_usd': 6276350000},
#  'EOS': {'Ticker': 'EOS',
#   'Price': 5.41698,
#   'Changes': 1.86,
#   'name': 'EOS',
#   'market_cap_usd': 4936450000},
#  'LTC': {'Ticker': 'LTC',
#   'Price': 87.638,
#   'Changes': 1.6,
#   'name': 'Litecoin',
#   'market_cap_usd': 5410550000},
#  'ADA': {'Ticker': 'ADA',
#   'Price': 0.0708406,
#   'Changes': 0.06,
#   'name': 'Cardano',
#   'market_cap_usd': 1836690000},
#  'XLM': {'Ticker': 'XLM',
#   'Price': 0.099908,
#   'Changes': 1.77,
#   'name': 'Stellar',
#   'market_cap_usd': 1916700000},
#  'MIOTA': {'Ticker': 'MIOTA',
#   'Price': 0.301348,
#   'Changes': -0.01,
#   'name': 'IOTA',
#   'market_cap_usd': 837606000},
#  'TRX': {'Ticker': 'TRX',
#   'Price': 0.0241723,
#   'Changes': -2.25,
#   'name': 'TRON',
#   'market_cap_usd': 1611860000},
#  'NEO': {'Ticker': 'NEO',
#   'Price': 9.47268,
#   'Changes': -1.11,
#   'name': 'NEO',
#   'market_cap_usd': 615724000},
#  'DASH': {'Ticker': 'DASH',
#   'Price': 121.718,
#   'Changes': 2,
#   'name': 'Dash',
#   'market_cap_usd': 1071480000},
#  'XMR': {'Ticker': 'XMR',
#   'Price': 74.8016,
#   'Changes': 2.69,
#   'name': 'Monero',
#   'market_cap_usd': 1269830000},
#  'XEM': {'Ticker': 'XEM',
#   'Price': 0.0565246,
#   'Changes': -0.22,
#   'name': 'NEM',
#   'market_cap_usd': 508722000},
#  'VEN': {'Ticker': 'VEN',
#   'Price': 1.73492,
#   'Changes': -13.36,
#   'name': 'VeChain',
#   'market_cap_usd': 962093000},
#  'ETC': {'Ticker': 'ETC',
#   'Price': 5.89601,
#   'Changes': -0.31,
#   'name': 'Ethereum Classic',
#   'market_cap_usd': 650903000},
#  'USDT': {'Ticker': 'USDT',
#   'Price': 1.00038,
#   'Changes': -0.35,
#   'name': 'Tether',
#   'market_cap_usd': 2779160000},
#  'QTUM': {'Ticker': 'QTUM',
#   'Price': 2.45568,
#   'Changes': -1.96,
#   'name': 'Qtum',
#   'market_cap_usd': 235043000},
#  'OMG': {'Ticker': 'OMG',
#   'Price': 1.69212,
#   'Changes': -2.73,
#   'name': 'OmiseGO',
#   'market_cap_usd': 237312000},
#  'ICX': {'Ticker': 'ICX',
#   'Price': 0.329284,
#   'Changes': -3.03,
#   'name': 'ICON',
#   'market_cap_usd': 155885000},
#  'BNB': {'Ticker': 'BNB',
#   'Price': 20.8867,
#   'Changes': 2.16,
#   'name': 'Binance Coin',
#   'market_cap_usd': 2948680000},
#  'LSK': {'Ticker': 'LSK',
#   'Price': 1.9057,
#   'Changes': 0.05,
#   'name': 'Lisk',
#   'market_cap_usd': 222705000},
#  'BTG': {'Ticker': 'BTG',
#   'Price': 22.1799,
#   'Changes': 5.64,
#   'name': 'Bitcoin Gold',
#   'market_cap_usd': 388457000},
#  'NANO': {'Ticker': 'NANO',
#   'Price': 1.674,
#   'Changes': 5.03,
#   'name': 'Nano',
#   'market_cap_usd': 223057000},
#  'BCN': {'Ticker': 'BCN',
#   'Price': 0.00100239,
#   'Changes': 3.19,
#   'name': 'Bytecoin',
#   'market_cap_usd': 184506000},
#  'XVG': {'Ticker': 'XVG',
#   'Price': 0.00729828,
#   'Changes': -1.52,
#   'name': 'Verge',
#   'market_cap_usd': 116839000},
#  'ZEC': {'Ticker': 'ZEC',
#   'Price': 61.475,
#   'Changes': 1.12,
#   'name': 'Zcash',
#   'market_cap_usd': 400545000},
#  'ONT': {'Ticker': 'ONT',
#   'Price': 1.16593,
#   'Changes': -1.04,
#   'name': 'Ontology',
#   'market_cap_usd': 577141000},
#  'AE': {'Ticker': 'AE',
#   'Price': 0.462911,
#   'Changes': -1.79,
#   'name': 'Aeternity',
#   'market_cap_usd': 122164000},
#  'STEEM': {'Ticker': 'STEEM',
#   'Price': 0.316151,
#   'Changes': -1.45,
#   'name': 'Steem',
#   'market_cap_usd': 101719000},
#  'ZIL': {'Ticker': 'ZIL',
#   'Price': 0.0155528,
#   'Changes': -9.35,
#   'name': 'Zilliqa',
#   'market_cap_usd': 135113000},
#  'WAN': {'Ticker': 'WAN',
#   'Price': 0.421985,
#   'Changes': 4.98,
#   'name': 'Wanchain',
#   'market_cap_usd': 44794800},
#  'SC': {'Ticker': 'SC',
#   'Price': 0.00289848,
#   'Changes': 9.47,
#   'name': 'Siacoin',
#   'market_cap_usd': 117836000},
#  'BTS': {'Ticker': 'BTS',
#   'Price': 0.055254,
#   'Changes': 3.4,
#   'name': 'BitShares',
#   'market_cap_usd': 150105000},
#  'BTM': {'Ticker': 'BTM',
#   'Price': 0.098824,
#   'Changes': -2.4,
#   'name': 'Bytom',
#   'market_cap_usd': 99070900},
#  'ZRX': {'Ticker': 'ZRX',
#   'Price': 0.276485,
#   'Changes': 0.44,
#   'name': '0x',
#   'market_cap_usd': 162568000},
#  'BCD': {'Ticker': 'BCD',
#   'Price': 0.932821,
#   'Changes': 3.6,
#   'name': 'Bitcoin Diamond',
#   'market_cap_usd': 173965000},
#  'PPT': {'Ticker': 'PPT',
#   'Price': 1.02713,
#   'Changes': -4.52,
#   'name': 'Populous',
#   'market_cap_usd': 54697100},
#  'STRAT': {'Ticker': 'STRAT',
#   'Price': 0.826122,
#   'Changes': -0.09,
#   'name': 'Stratis',
#   'market_cap_usd': 82054000},
#  'WAVES': {'Ticker': 'WAVES',
#   'Price': 2.44445,
#   'Changes': 1.27,
#   'name': 'Waves',
#   'market_cap_usd': 244445000},
#  'BTCP': {'Ticker': 'BTCP',
#   'Price': 1.73003,
#   'Changes': -0.18,
#   'name': 'Bitcoin Private',
#   'market_cap_usd': 35508000},
#  'MKR': {'Ticker': 'MKR',
#   'Price': 574.465,
#   'Changes': 2.37,
#   'name': 'Maker',
#   'market_cap_usd': 574465000},
#  'RHOC': {'Ticker': 'RHOC',
#   'Price': 0.152374,
#   'Changes': -3.89,
#   'name': 'RChain',
#   'market_cap_usd': 58946000},
#  'DCR': {'Ticker': 'DCR',
#   'Price': 27.4313,
#   'Changes': 2.16,
#   'name': 'Decred',
#   'market_cap_usd': 267912000},
#  'GNT': {'Ticker': 'GNT',
#   'Price': 0.071437,
#   'Changes': -2.39,
#   'name': 'Golem',
#   'market_cap_usd': 68838200},
#  'DOGE': {'Ticker': 'DOGE',
#   'Price': 0.00271699,
#   'Changes': 5.38,
#   'name': 'Dogecoin',
#   'market_cap_usd': 324576000},
#  'SNT': {'Ticker': 'SNT',
#   'Price': 0.0224258,
#   'Changes': -3.79,
#   'name': 'Status',
#   'market_cap_usd': 77828400},
#  'HSR': {'Ticker': 'HSR',
#   'Price': 2.13033,
#   'Changes': -7.3,
#   'name': 'Hshare',
#   'market_cap_usd': 92721900},
#  'IOST': {'Ticker': 'IOST',
#   'Price': 0.012916,
#   'Changes': 0.7,
#   'name': 'IOStoken',
#   'market_cap_usd': 155172000},
#  'WTC': {'Ticker': 'WTC',
#   'Price': 1.95039,
#   'Changes': -4.05,
#   'name': 'Waltonchain',
#   'market_cap_usd': 81296900},
#  'DGD': {'Ticker': 'DGD',
#   'Price': 36.7016,
#   'Changes': 1.72,
#   'name': 'DigixDAO',
#   'market_cap_usd': 73403300},
#  'LRC': {'Ticker': 'LRC',
#   'Price': 0.0592044,
#   'Changes': 4.13,
#   'name': 'Loopring',
#   'market_cap_usd': 49077700},
#  'DGB': {'Ticker': 'DGB',
#   'Price': 0.0110698,
#   'Changes': 2.56,
#   'name': 'DigiByte',
#   'market_cap_usd': 130426000},
#  'BAT': {'Ticker': 'BAT',
#   'Price': 0.354517,
#   'Changes': -1.16,
#   'name': 'Basic Attention Token',
#   'market_cap_usd': 447190000},
#  'AION': {'Ticker': 'AION',
#   'Price': 0.20355,
#   'Changes': 3.19,
#   'name': 'Aion',
#   'market_cap_usd': 63015400},
#  'REP': {'Ticker': 'REP',
#   'Price': 20.4049,
#   'Changes': 0.39,
#   'name': 'Augur',
#   'market_cap_usd': 224454000},
#  'XIN': {'Ticker': 'XIN',
#   'Price': 187.053,
#   'Changes': 5.71,
#   'name': 'Mixin',
#   'market_cap_usd': 82896100},
#  'KMD': {'Ticker': 'KMD',
#   'Price': 1.1096,
#   'Changes': -4.05,
#   'name': 'Komodo',
#   'market_cap_usd': 125647000},
#  'ARDR': {'Ticker': 'ARDR',
#   'Price': 0.073039,
#   'Changes': -0.66,
#   'name': 'Ardor',
#   'market_cap_usd': 72965900},
#  'ELF': {'Ticker': 'ELF',
#   'Price': 0.167023,
#   'Changes': 0.86,
#   'name': 'aelf',
#   'market_cap_usd': 58591700},
#  'MITH': {'Ticker': 'MITH',
#   'Price': 0.0705949,
#   'Changes': 1.94,
#   'name': 'Mithril',
#   'market_cap_usd': 34368400},
#  'NOTE': {'Ticker': 'NOTE',
#   'Price': 2.54893,
#   'Changes': 346.82,
#   'name': 'DNotes',
#   'market_cap_usd': 392180000},
#  'LOOM': {'Ticker': 'LOOM',
#   'Price': 0.0599882,
#   'Changes': -7.51,
#   'name': 'Loom Network',
#   'market_cap_usd': 47337100},
#  'NAS': {'Ticker': 'NAS',
#   'Price': 1.03582,
#   'Changes': 3.5,
#   'name': 'Nebulas',
#   'market_cap_usd': 47129600},
#  'ARK': {'Ticker': 'ARK',
#   'Price': 0.502392,
#   'Changes': 1.92,
#   'name': 'Ark',
#   'market_cap_usd': 56345200},
#  'KCS': {'Ticker': 'KCS',
#   'Price': 1.04323,
#   'Changes': 0.5,
#   'name': 'KuCoin Shares',
#   'market_cap_usd': 93535000},
#  'KNC': {'Ticker': 'KNC',
#   'Price': 0.323185,
#   'Changes': 17.39,
#   'name': 'Kyber Network',
#   'market_cap_usd': 53847400},
#  'GAS': {'Ticker': 'GAS',
#   'Price': 8.23719,
#   'Changes': 60.74,
#   'name': 'Gas',
#   'market_cap_usd': 83429300},
#  'PIVX': {'Ticker': 'PIVX',
#   'Price': 0.921548,
#   'Changes': 0.53,
#   'name': 'PIVX',
#   'market_cap_usd': 52326600},
#  'RDD': {'Ticker': 'RDD',
#   'Price': 0.00174459,
#   'Changes': 5.66,
#   'name': 'ReddCoin',
#   'market_cap_usd': 50259500},
#  'WICC': {'Ticker': 'WICC',
#   'Price': 0.259072,
#   'Changes': -5.66,
#   'name': 'WaykiChain',
#   'market_cap_usd': 48964600},
#  'SUB': {'Ticker': 'SUB',
#   'Price': 0.178403,
#   'Changes': -8.63,
#   'name': 'Substratum',
#   'market_cap_usd': 68332000},
#  'CTXC': {'Ticker': 'CTXC',
#   'Price': 0.33038,
#   'Changes': 1.82,
#   'name': 'Cortex',
#   'market_cap_usd': 49488400},
#  'MONA': {'Ticker': 'MONA',
#   'Price': 0.927014,
#   'Changes': -0.34,
#   'name': 'MonaCoin',
#   'market_cap_usd': 60932400},
#  'SYS': {'Ticker': 'SYS',
#   'Price': 0.0978142,
#   'Changes': 6.21,
#   'name': 'Syscoin',
#   'market_cap_usd': 52673200},
#  'CENNZ': {'Ticker': 'CENNZ',
#   'Price': 0.0382512,
#   'Changes': -3.26,
#   'name': 'Centrality',
#   'market_cap_usd': 30653800},
#  'QASH': {'Ticker': 'QASH',
#   'Price': 0.153433,
#   'Changes': -2.85,
#   'name': 'QASH',
#   'market_cap_usd': 53701600},
#  'NPXS': {'Ticker': 'NPXS',
#   'Price': 0.000610296,
#   'Changes': -3.12,
#   'name': 'Pundi X',
#   'market_cap_usd': 129396000},
#  'CNX': {'Ticker': 'CNX',
#   'Price': 1.57353,
#   'Changes': 6.15,
#   'name': 'Cryptonex',
#   'market_cap_usd': 87623900},
#  'DRGN': {'Ticker': 'DRGN',
#   'Price': 0.240251,
#   'Changes': 3.89,
#   'name': 'Dragonchain',
#   'market_cap_usd': 57281200},
#  'BNT': {'Ticker': 'BNT',
#   'Price': 0.6474,
#   'Changes': -11.33,
#   'name': 'Bancor',
#   'market_cap_usd': 40674500},
#  'GXS': {'Ticker': 'GXS',
#   'Price': 0.501727,
#   'Changes': 6.74,
#   'name': 'GXChain',
#   'market_cap_usd': 30103600},
#  'ETHOS': {'Ticker': 'ETHOS',
#   'Price': 1.24701,
#   'Changes': 5.1,
#   'name': 'Ethos',
#   'market_cap_usd': 96458600},
#  'STORM': {'Ticker': 'STORM',
#   'Price': 0.021722,
#   'Changes': 10.4,
#   'name': 'Storm',
#   'market_cap_usd': 97622200},
#  'VERI': {'Ticker': 'VERI',
#   'Price': 16.8482,
#   'Changes': -6.22,
#   'name': 'Veritaseum',
#   'market_cap_usd': 36217600},
#  'FUN': {'Ticker': 'FUN',
#   'Price': 0.0122788,
#   'Changes': 0.07,
#   'name': 'FunFair',
#   'market_cap_usd': 65886000},
#  'WAX': {'Ticker': 'WAX',
#   'Price': 0.0652349,
#   'Changes': -0.37,
#   'name': 'WAX',
#   'market_cap_usd': 61499100},
#  'NXT': {'Ticker': 'NXT',
#   'Price': 0.0302068,
#   'Changes': 5.63,
#   'name': 'Nxt',
#   'market_cap_usd': 30176600},
#  'DCN': {'Ticker': 'DCN',
#   'Price': 0.00014762,
#   'Changes': -0.72,
#   'name': 'Dentacoin',
#   'market_cap_usd': 48245500},
#  'FSN': {'Ticker': 'FSN',
#   'Price': 2.96575,
#   'Changes': -0.66,
#   'name': 'Fusion',
#   'market_cap_usd': 88036300},
#  'FCT': {'Ticker': 'FCT',
#   'Price': 9.70626,
#   'Changes': 0.81,
#   'name': 'Factom',
#   'market_cap_usd': 91843600},
#  'ELA': {'Ticker': 'ELA',
#   'Price': 3.39606,
#   'Changes': 4.12,
#   'name': 'Elastos',
#   'market_cap_usd': 52004700},
#  'SALT': {'Ticker': 'SALT',
#   'Price': 0.772418,
#   'Changes': -0.62,
#   'name': 'SALT',
#   'market_cap_usd': 63686400},
#  'GTO': {'Ticker': 'GTO',
#   'Price': 0.171439,
#   'Changes': 7.16,
#   'name': 'Gifto',
#   'market_cap_usd': 91511800},
#  'ETN': {'Ticker': 'ETN',
#   'Price': 0.00514456,
#   'Changes': 3.22,
#   'name': 'Electroneum',
#   'market_cap_usd': 48440400},
#  'ENG': {'Ticker': 'ENG',
#   'Price': 0.712045,
#   'Changes': 6.03,
#   'name': 'Enigma',
#   'market_cap_usd': 53286700},
#  'XZC': {'Ticker': 'XZC',
#   'Price': 6.90169,
#   'Changes': 7.78,
#   'name': 'ZCoin',
#   'market_cap_usd': 51530200},
#  'LINK': {'Ticker': 'LINK',
#   'Price': 0.647219,
#   'Changes': -3.95,
#   'name': 'ChainLink',
#   'market_cap_usd': 226527000},
#  'POLY': {'Ticker': 'POLY',
#   'Price': 0.118469,
#   'Changes': -14.03,
#   'name': 'Polymath',
#   'market_cap_usd': 41276000},
#  'POWR': {'Ticker': 'POWR',
#   'Price': 0.116454,
#   'Changes': 5.86,
#   'name': 'Power Ledger',
#   'market_cap_usd': 47146600}}

# %% [markdown]
# Now that we know the steps needed to be executed for us to obtain parsed data, we can consolidate those commands into a our own defined function.

# %%
def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url)
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
# Try out our newly defined function
crypto_data_parsed = get_jsonparsed_data(crypto_url)
crypto_data_parsed
# Out:
# {'BTC': {'Ticker': 'BTC',
#   'Price': 7154.05,
#   'Changes': 5.45,
#   'name': 'Bitcoin',
#   'market_cap_usd': 126597000000},
#  'ETH': {'Ticker': 'ETH',
#   'Price': 189.619,
#   'Changes': 0.2,
#   'name': 'Ethereum',
#   'market_cap_usd': 20106500000},
#  'XRP': {'Ticker': 'XRP',
#   'Price': 0.312575,
#   'Changes': -0.24,
#   'name': 'Ripple',
#   'market_cap_usd': 13169800000},
#  'BCH': {'Ticker': 'BCH',
#   'Price': 353.042,
#   'Changes': 10.14,
#   'name': 'Bitcoin Cash',
#   'market_cap_usd': 6276350000},
#  'EOS': {'Ticker': 'EOS',
#   'Price': 5.41698,
#   'Changes': 1.86,
#   'name': 'EOS',
#   'market_cap_usd': 4936450000},
#  'LTC': {'Ticker': 'LTC',
#   'Price': 87.638,
#   'Changes': 1.6,
#   'name': 'Litecoin',
#   'market_cap_usd': 5410550000},
#  'ADA': {'Ticker': 'ADA',
#   'Price': 0.0708406,
#   'Changes': 0.06,
#   'name': 'Cardano',
#   'market_cap_usd': 1836690000},
#  'XLM': {'Ticker': 'XLM',
#   'Price': 0.099908,
#   'Changes': 1.77,
#   'name': 'Stellar',
#   'market_cap_usd': 1916700000},
#  'MIOTA': {'Ticker': 'MIOTA',
#   'Price': 0.301348,
#   'Changes': -0.01,
#   'name': 'IOTA',
#   'market_cap_usd': 837606000},
#  'TRX': {'Ticker': 'TRX',
#   'Price': 0.0241723,
#   'Changes': -2.25,
#   'name': 'TRON',
#   'market_cap_usd': 1611860000},
#  'NEO': {'Ticker': 'NEO',
#   'Price': 9.47268,
#   'Changes': -1.11,
#   'name': 'NEO',
#   'market_cap_usd': 615724000},
#  'DASH': {'Ticker': 'DASH',
#   'Price': 121.718,
#   'Changes': 2,
#   'name': 'Dash',
#   'market_cap_usd': 1071480000},
#  'XMR': {'Ticker': 'XMR',
#   'Price': 74.8016,
#   'Changes': 2.69,
#   'name': 'Monero',
#   'market_cap_usd': 1269830000},
#  'XEM': {'Ticker': 'XEM',
#   'Price': 0.0565246,
#   'Changes': -0.22,
#   'name': 'NEM',
#   'market_cap_usd': 508722000},
#  'VEN': {'Ticker': 'VEN',
#   'Price': 1.73492,
#   'Changes': -13.36,
#   'name': 'VeChain',
#   'market_cap_usd': 962093000},
#  'ETC': {'Ticker': 'ETC',
#   'Price': 5.89601,
#   'Changes': -0.31,
#   'name': 'Ethereum Classic',
#   'market_cap_usd': 650903000},
#  'USDT': {'Ticker': 'USDT',
#   'Price': 1.00038,
#   'Changes': -0.35,
#   'name': 'Tether',
#   'market_cap_usd': 2779160000},
#  'QTUM': {'Ticker': 'QTUM',
#   'Price': 2.45568,
#   'Changes': -1.96,
#   'name': 'Qtum',
#   'market_cap_usd': 235043000},
#  'OMG': {'Ticker': 'OMG',
#   'Price': 1.69212,
#   'Changes': -2.73,
#   'name': 'OmiseGO',
#   'market_cap_usd': 237312000},
#  'ICX': {'Ticker': 'ICX',
#   'Price': 0.329284,
#   'Changes': -3.03,
#   'name': 'ICON',
#   'market_cap_usd': 155885000},
#  'BNB': {'Ticker': 'BNB',
#   'Price': 20.8867,
#   'Changes': 2.16,
#   'name': 'Binance Coin',
#   'market_cap_usd': 2948680000},
#  'LSK': {'Ticker': 'LSK',
#   'Price': 1.9057,
#   'Changes': 0.05,
#   'name': 'Lisk',
#   'market_cap_usd': 222705000},
#  'BTG': {'Ticker': 'BTG',
#   'Price': 22.1799,
#   'Changes': 5.64,
#   'name': 'Bitcoin Gold',
#   'market_cap_usd': 388457000},
#  'NANO': {'Ticker': 'NANO',
#   'Price': 1.674,
#   'Changes': 5.03,
#   'name': 'Nano',
#   'market_cap_usd': 223057000},
#  'BCN': {'Ticker': 'BCN',
#   'Price': 0.00100239,
#   'Changes': 3.19,
#   'name': 'Bytecoin',
#   'market_cap_usd': 184506000},
#  'XVG': {'Ticker': 'XVG',
#   'Price': 0.00729828,
#   'Changes': -1.52,
#   'name': 'Verge',
#   'market_cap_usd': 116839000},
#  'ZEC': {'Ticker': 'ZEC',
#   'Price': 61.475,
#   'Changes': 1.12,
#   'name': 'Zcash',
#   'market_cap_usd': 400545000},
#  'ONT': {'Ticker': 'ONT',
#   'Price': 1.16593,
#   'Changes': -1.04,
#   'name': 'Ontology',
#   'market_cap_usd': 577141000},
#  'AE': {'Ticker': 'AE',
#   'Price': 0.462911,
#   'Changes': -1.79,
#   'name': 'Aeternity',
#   'market_cap_usd': 122164000},
#  'STEEM': {'Ticker': 'STEEM',
#   'Price': 0.316151,
#   'Changes': -1.45,
#   'name': 'Steem',
#   'market_cap_usd': 101719000},
#  'ZIL': {'Ticker': 'ZIL',
#   'Price': 0.0155528,
#   'Changes': -9.35,
#   'name': 'Zilliqa',
#   'market_cap_usd': 135113000},
#  'WAN': {'Ticker': 'WAN',
#   'Price': 0.421985,
#   'Changes': 4.98,
#   'name': 'Wanchain',
#   'market_cap_usd': 44794800},
#  'SC': {'Ticker': 'SC',
#   'Price': 0.00289848,
#   'Changes': 9.47,
#   'name': 'Siacoin',
#   'market_cap_usd': 117836000},
#  'BTS': {'Ticker': 'BTS',
#   'Price': 0.055254,
#   'Changes': 3.4,
#   'name': 'BitShares',
#   'market_cap_usd': 150105000},
#  'BTM': {'Ticker': 'BTM',
#   'Price': 0.098824,
#   'Changes': -2.4,
#   'name': 'Bytom',
#   'market_cap_usd': 99070900},
#  'ZRX': {'Ticker': 'ZRX',
#   'Price': 0.276485,
#   'Changes': 0.44,
#   'name': '0x',
#   'market_cap_usd': 162568000},
#  'BCD': {'Ticker': 'BCD',
#   'Price': 0.932821,
#   'Changes': 3.6,
#   'name': 'Bitcoin Diamond',
#   'market_cap_usd': 173965000},
#  'PPT': {'Ticker': 'PPT',
#   'Price': 1.02713,
#   'Changes': -4.52,
#   'name': 'Populous',
#   'market_cap_usd': 54697100},
#  'STRAT': {'Ticker': 'STRAT',
#   'Price': 0.826122,
#   'Changes': -0.09,
#   'name': 'Stratis',
#   'market_cap_usd': 82054000},
#  'WAVES': {'Ticker': 'WAVES',
#   'Price': 2.44445,
#   'Changes': 1.27,
#   'name': 'Waves',
#   'market_cap_usd': 244445000},
#  'BTCP': {'Ticker': 'BTCP',
#   'Price': 1.73003,
#   'Changes': -0.18,
#   'name': 'Bitcoin Private',
#   'market_cap_usd': 35508000},
#  'MKR': {'Ticker': 'MKR',
#   'Price': 574.465,
#   'Changes': 2.37,
#   'name': 'Maker',
#   'market_cap_usd': 574465000},
#  'RHOC': {'Ticker': 'RHOC',
#   'Price': 0.152374,
#   'Changes': -3.89,
#   'name': 'RChain',
#   'market_cap_usd': 58946000},
#  'DCR': {'Ticker': 'DCR',
#   'Price': 27.4313,
#   'Changes': 2.16,
#   'name': 'Decred',
#   'market_cap_usd': 267912000},
#  'GNT': {'Ticker': 'GNT',
#   'Price': 0.071437,
#   'Changes': -2.39,
#   'name': 'Golem',
#   'market_cap_usd': 68838200},
#  'DOGE': {'Ticker': 'DOGE',
#   'Price': 0.00271699,
#   'Changes': 5.38,
#   'name': 'Dogecoin',
#   'market_cap_usd': 324576000},
#  'SNT': {'Ticker': 'SNT',
#   'Price': 0.0224258,
#   'Changes': -3.79,
#   'name': 'Status',
#   'market_cap_usd': 77828400},
#  'HSR': {'Ticker': 'HSR',
#   'Price': 2.13033,
#   'Changes': -7.3,
#   'name': 'Hshare',
#   'market_cap_usd': 92721900},
#  'IOST': {'Ticker': 'IOST',
#   'Price': 0.012916,
#   'Changes': 0.7,
#   'name': 'IOStoken',
#   'market_cap_usd': 155172000},
#  'WTC': {'Ticker': 'WTC',
#   'Price': 1.95039,
#   'Changes': -4.05,
#   'name': 'Waltonchain',
#   'market_cap_usd': 81296900},
#  'DGD': {'Ticker': 'DGD',
#   'Price': 36.7016,
#   'Changes': 1.72,
#   'name': 'DigixDAO',
#   'market_cap_usd': 73403300},
#  'LRC': {'Ticker': 'LRC',
#   'Price': 0.0592044,
#   'Changes': 4.13,
#   'name': 'Loopring',
#   'market_cap_usd': 49077700},
#  'DGB': {'Ticker': 'DGB',
#   'Price': 0.0110698,
#   'Changes': 2.56,
#   'name': 'DigiByte',
#   'market_cap_usd': 130426000},
#  'BAT': {'Ticker': 'BAT',
#   'Price': 0.354517,
#   'Changes': -1.16,
#   'name': 'Basic Attention Token',
#   'market_cap_usd': 447190000},
#  'AION': {'Ticker': 'AION',
#   'Price': 0.20355,
#   'Changes': 3.19,
#   'name': 'Aion',
#   'market_cap_usd': 63015400},
#  'REP': {'Ticker': 'REP',
#   'Price': 20.4049,
#   'Changes': 0.39,
#   'name': 'Augur',
#   'market_cap_usd': 224454000},
#  'XIN': {'Ticker': 'XIN',
#   'Price': 187.053,
#   'Changes': 5.71,
#   'name': 'Mixin',
#   'market_cap_usd': 82896100},
#  'KMD': {'Ticker': 'KMD',
#   'Price': 1.1096,
#   'Changes': -4.05,
#   'name': 'Komodo',
#   'market_cap_usd': 125647000},
#  'ARDR': {'Ticker': 'ARDR',
#   'Price': 0.073039,
#   'Changes': -0.66,
#   'name': 'Ardor',
#   'market_cap_usd': 72965900},
#  'ELF': {'Ticker': 'ELF',
#   'Price': 0.167023,
#   'Changes': 0.86,
#   'name': 'aelf',
#   'market_cap_usd': 58591700},
#  'MITH': {'Ticker': 'MITH',
#   'Price': 0.0705949,
#   'Changes': 1.94,
#   'name': 'Mithril',
#   'market_cap_usd': 34368400},
#  'NOTE': {'Ticker': 'NOTE',
#   'Price': 2.54893,
#   'Changes': 346.82,
#   'name': 'DNotes',
#   'market_cap_usd': 392180000},
#  'LOOM': {'Ticker': 'LOOM',
#   'Price': 0.0599882,
#   'Changes': -7.51,
#   'name': 'Loom Network',
#   'market_cap_usd': 47337100},
#  'NAS': {'Ticker': 'NAS',
#   'Price': 1.03582,
#   'Changes': 3.5,
#   'name': 'Nebulas',
#   'market_cap_usd': 47129600},
#  'ARK': {'Ticker': 'ARK',
#   'Price': 0.502392,
#   'Changes': 1.92,
#   'name': 'Ark',
#   'market_cap_usd': 56345200},
#  'KCS': {'Ticker': 'KCS',
#   'Price': 1.04323,
#   'Changes': 0.5,
#   'name': 'KuCoin Shares',
#   'market_cap_usd': 93535000},
#  'KNC': {'Ticker': 'KNC',
#   'Price': 0.323185,
#   'Changes': 17.39,
#   'name': 'Kyber Network',
#   'market_cap_usd': 53847400},
#  'GAS': {'Ticker': 'GAS',
#   'Price': 8.23719,
#   'Changes': 60.74,
#   'name': 'Gas',
#   'market_cap_usd': 83429300},
#  'PIVX': {'Ticker': 'PIVX',
#   'Price': 0.921548,
#   'Changes': 0.53,
#   'name': 'PIVX',
#   'market_cap_usd': 52326600},
#  'RDD': {'Ticker': 'RDD',
#   'Price': 0.00174459,
#   'Changes': 5.66,
#   'name': 'ReddCoin',
#   'market_cap_usd': 50259500},
#  'WICC': {'Ticker': 'WICC',
#   'Price': 0.259072,
#   'Changes': -5.66,
#   'name': 'WaykiChain',
#   'market_cap_usd': 48964600},
#  'SUB': {'Ticker': 'SUB',
#   'Price': 0.178403,
#   'Changes': -8.63,
#   'name': 'Substratum',
#   'market_cap_usd': 68332000},
#  'CTXC': {'Ticker': 'CTXC',
#   'Price': 0.33038,
#   'Changes': 1.82,
#   'name': 'Cortex',
#   'market_cap_usd': 49488400},
#  'MONA': {'Ticker': 'MONA',
#   'Price': 0.927014,
#   'Changes': -0.34,
#   'name': 'MonaCoin',
#   'market_cap_usd': 60932400},
#  'SYS': {'Ticker': 'SYS',
#   'Price': 0.0978142,
#   'Changes': 6.21,
#   'name': 'Syscoin',
#   'market_cap_usd': 52673200},
#  'CENNZ': {'Ticker': 'CENNZ',
#   'Price': 0.0382512,
#   'Changes': -3.26,
#   'name': 'Centrality',
#   'market_cap_usd': 30653800},
#  'QASH': {'Ticker': 'QASH',
#   'Price': 0.153433,
#   'Changes': -2.85,
#   'name': 'QASH',
#   'market_cap_usd': 53701600},
#  'NPXS': {'Ticker': 'NPXS',
#   'Price': 0.000610296,
#   'Changes': -3.12,
#   'name': 'Pundi X',
#   'market_cap_usd': 129396000},
#  'CNX': {'Ticker': 'CNX',
#   'Price': 1.57353,
#   'Changes': 6.15,
#   'name': 'Cryptonex',
#   'market_cap_usd': 87623900},
#  'DRGN': {'Ticker': 'DRGN',
#   'Price': 0.240251,
#   'Changes': 3.89,
#   'name': 'Dragonchain',
#   'market_cap_usd': 57281200},
#  'BNT': {'Ticker': 'BNT',
#   'Price': 0.6474,
#   'Changes': -11.33,
#   'name': 'Bancor',
#   'market_cap_usd': 40674500},
#  'GXS': {'Ticker': 'GXS',
#   'Price': 0.501727,
#   'Changes': 6.74,
#   'name': 'GXChain',
#   'market_cap_usd': 30103600},
#  'ETHOS': {'Ticker': 'ETHOS',
#   'Price': 1.24701,
#   'Changes': 5.1,
#   'name': 'Ethos',
#   'market_cap_usd': 96458600},
#  'STORM': {'Ticker': 'STORM',
#   'Price': 0.021722,
#   'Changes': 10.4,
#   'name': 'Storm',
#   'market_cap_usd': 97622200},
#  'VERI': {'Ticker': 'VERI',
#   'Price': 16.8482,
#   'Changes': -6.22,
#   'name': 'Veritaseum',
#   'market_cap_usd': 36217600},
#  'FUN': {'Ticker': 'FUN',
#   'Price': 0.0122788,
#   'Changes': 0.07,
#   'name': 'FunFair',
#   'market_cap_usd': 65886000},
#  'WAX': {'Ticker': 'WAX',
#   'Price': 0.0652349,
#   'Changes': -0.37,
#   'name': 'WAX',
#   'market_cap_usd': 61499100},
#  'NXT': {'Ticker': 'NXT',
#   'Price': 0.0302068,
#   'Changes': 5.63,
#   'name': 'Nxt',
#   'market_cap_usd': 30176600},
#  'DCN': {'Ticker': 'DCN',
#   'Price': 0.00014762,
#   'Changes': -0.72,
#   'name': 'Dentacoin',
#   'market_cap_usd': 48245500},
#  'FSN': {'Ticker': 'FSN',
#   'Price': 2.96575,
#   'Changes': -0.66,
#   'name': 'Fusion',
#   'market_cap_usd': 88036300},
#  'FCT': {'Ticker': 'FCT',
#   'Price': 9.70626,
#   'Changes': 0.81,
#   'name': 'Factom',
#   'market_cap_usd': 91843600},
#  'ELA': {'Ticker': 'ELA',
#   'Price': 3.39606,
#   'Changes': 4.12,
#   'name': 'Elastos',
#   'market_cap_usd': 52004700},
#  'SALT': {'Ticker': 'SALT',
#   'Price': 0.772418,
#   'Changes': -0.62,
#   'name': 'SALT',
#   'market_cap_usd': 63686400},
#  'GTO': {'Ticker': 'GTO',
#   'Price': 0.171439,
#   'Changes': 7.16,
#   'name': 'Gifto',
#   'market_cap_usd': 91511800},
#  'ETN': {'Ticker': 'ETN',
#   'Price': 0.00514456,
#   'Changes': 3.22,
#   'name': 'Electroneum',
#   'market_cap_usd': 48440400},
#  'ENG': {'Ticker': 'ENG',
#   'Price': 0.712045,
#   'Changes': 6.03,
#   'name': 'Enigma',
#   'market_cap_usd': 53286700},
#  'XZC': {'Ticker': 'XZC',
#   'Price': 6.90169,
#   'Changes': 7.78,
#   'name': 'ZCoin',
#   'market_cap_usd': 51530200},
#  'LINK': {'Ticker': 'LINK',
#   'Price': 0.647219,
#   'Changes': -3.95,
#   'name': 'ChainLink',
#   'market_cap_usd': 226527000},
#  'POLY': {'Ticker': 'POLY',
#   'Price': 0.118469,
#   'Changes': -14.03,
#   'name': 'Polymath',
#   'market_cap_usd': 41276000},
#  'POWR': {'Ticker': 'POWR',
#   'Price': 0.116454,
#   'Changes': 5.86,
#   'name': 'Power Ledger',
#   'market_cap_usd': 47146600}}

# %% [markdown]
# ## Indexing from parsed data (through dictionary keys)

# %%
crypto_data_parsed
# Out:
# {'BTC': {'Ticker': 'BTC',
#   'Price': 7154.05,
#   'Changes': 5.45,
#   'name': 'Bitcoin',
#   'market_cap_usd': 126597000000},
#  'ETH': {'Ticker': 'ETH',
#   'Price': 189.619,
#   'Changes': 0.2,
#   'name': 'Ethereum',
#   'market_cap_usd': 20106500000},
#  'XRP': {'Ticker': 'XRP',
#   'Price': 0.312575,
#   'Changes': -0.24,
#   'name': 'Ripple',
#   'market_cap_usd': 13169800000},
#  'BCH': {'Ticker': 'BCH',
#   'Price': 353.042,
#   'Changes': 10.14,
#   'name': 'Bitcoin Cash',
#   'market_cap_usd': 6276350000},
#  'EOS': {'Ticker': 'EOS',
#   'Price': 5.41698,
#   'Changes': 1.86,
#   'name': 'EOS',
#   'market_cap_usd': 4936450000},
#  'LTC': {'Ticker': 'LTC',
#   'Price': 87.638,
#   'Changes': 1.6,
#   'name': 'Litecoin',
#   'market_cap_usd': 5410550000},
#  'ADA': {'Ticker': 'ADA',
#   'Price': 0.0708406,
#   'Changes': 0.06,
#   'name': 'Cardano',
#   'market_cap_usd': 1836690000},
#  'XLM': {'Ticker': 'XLM',
#   'Price': 0.099908,
#   'Changes': 1.77,
#   'name': 'Stellar',
#   'market_cap_usd': 1916700000},
#  'MIOTA': {'Ticker': 'MIOTA',
#   'Price': 0.301348,
#   'Changes': -0.01,
#   'name': 'IOTA',
#   'market_cap_usd': 837606000},
#  'TRX': {'Ticker': 'TRX',
#   'Price': 0.0241723,
#   'Changes': -2.25,
#   'name': 'TRON',
#   'market_cap_usd': 1611860000},
#  'NEO': {'Ticker': 'NEO',
#   'Price': 9.47268,
#   'Changes': -1.11,
#   'name': 'NEO',
#   'market_cap_usd': 615724000},
#  'DASH': {'Ticker': 'DASH',
#   'Price': 121.718,
#   'Changes': 2,
#   'name': 'Dash',
#   'market_cap_usd': 1071480000},
#  'XMR': {'Ticker': 'XMR',
#   'Price': 74.8016,
#   'Changes': 2.69,
#   'name': 'Monero',
#   'market_cap_usd': 1269830000},
#  'XEM': {'Ticker': 'XEM',
#   'Price': 0.0565246,
#   'Changes': -0.22,
#   'name': 'NEM',
#   'market_cap_usd': 508722000},
#  'VEN': {'Ticker': 'VEN',
#   'Price': 1.73492,
#   'Changes': -13.36,
#   'name': 'VeChain',
#   'market_cap_usd': 962093000},
#  'ETC': {'Ticker': 'ETC',
#   'Price': 5.89601,
#   'Changes': -0.31,
#   'name': 'Ethereum Classic',
#   'market_cap_usd': 650903000},
#  'USDT': {'Ticker': 'USDT',
#   'Price': 1.00038,
#   'Changes': -0.35,
#   'name': 'Tether',
#   'market_cap_usd': 2779160000},
#  'QTUM': {'Ticker': 'QTUM',
#   'Price': 2.45568,
#   'Changes': -1.96,
#   'name': 'Qtum',
#   'market_cap_usd': 235043000},
#  'OMG': {'Ticker': 'OMG',
#   'Price': 1.69212,
#   'Changes': -2.73,
#   'name': 'OmiseGO',
#   'market_cap_usd': 237312000},
#  'ICX': {'Ticker': 'ICX',
#   'Price': 0.329284,
#   'Changes': -3.03,
#   'name': 'ICON',
#   'market_cap_usd': 155885000},
#  'BNB': {'Ticker': 'BNB',
#   'Price': 20.8867,
#   'Changes': 2.16,
#   'name': 'Binance Coin',
#   'market_cap_usd': 2948680000},
#  'LSK': {'Ticker': 'LSK',
#   'Price': 1.9057,
#   'Changes': 0.05,
#   'name': 'Lisk',
#   'market_cap_usd': 222705000},
#  'BTG': {'Ticker': 'BTG',
#   'Price': 22.1799,
#   'Changes': 5.64,
#   'name': 'Bitcoin Gold',
#   'market_cap_usd': 388457000},
#  'NANO': {'Ticker': 'NANO',
#   'Price': 1.674,
#   'Changes': 5.03,
#   'name': 'Nano',
#   'market_cap_usd': 223057000},
#  'BCN': {'Ticker': 'BCN',
#   'Price': 0.00100239,
#   'Changes': 3.19,
#   'name': 'Bytecoin',
#   'market_cap_usd': 184506000},
#  'XVG': {'Ticker': 'XVG',
#   'Price': 0.00729828,
#   'Changes': -1.52,
#   'name': 'Verge',
#   'market_cap_usd': 116839000},
#  'ZEC': {'Ticker': 'ZEC',
#   'Price': 61.475,
#   'Changes': 1.12,
#   'name': 'Zcash',
#   'market_cap_usd': 400545000},
#  'ONT': {'Ticker': 'ONT',
#   'Price': 1.16593,
#   'Changes': -1.04,
#   'name': 'Ontology',
#   'market_cap_usd': 577141000},
#  'AE': {'Ticker': 'AE',
#   'Price': 0.462911,
#   'Changes': -1.79,
#   'name': 'Aeternity',
#   'market_cap_usd': 122164000},
#  'STEEM': {'Ticker': 'STEEM',
#   'Price': 0.316151,
#   'Changes': -1.45,
#   'name': 'Steem',
#   'market_cap_usd': 101719000},
#  'ZIL': {'Ticker': 'ZIL',
#   'Price': 0.0155528,
#   'Changes': -9.35,
#   'name': 'Zilliqa',
#   'market_cap_usd': 135113000},
#  'WAN': {'Ticker': 'WAN',
#   'Price': 0.421985,
#   'Changes': 4.98,
#   'name': 'Wanchain',
#   'market_cap_usd': 44794800},
#  'SC': {'Ticker': 'SC',
#   'Price': 0.00289848,
#   'Changes': 9.47,
#   'name': 'Siacoin',
#   'market_cap_usd': 117836000},
#  'BTS': {'Ticker': 'BTS',
#   'Price': 0.055254,
#   'Changes': 3.4,
#   'name': 'BitShares',
#   'market_cap_usd': 150105000},
#  'BTM': {'Ticker': 'BTM',
#   'Price': 0.098824,
#   'Changes': -2.4,
#   'name': 'Bytom',
#   'market_cap_usd': 99070900},
#  'ZRX': {'Ticker': 'ZRX',
#   'Price': 0.276485,
#   'Changes': 0.44,
#   'name': '0x',
#   'market_cap_usd': 162568000},
#  'BCD': {'Ticker': 'BCD',
#   'Price': 0.932821,
#   'Changes': 3.6,
#   'name': 'Bitcoin Diamond',
#   'market_cap_usd': 173965000},
#  'PPT': {'Ticker': 'PPT',
#   'Price': 1.02713,
#   'Changes': -4.52,
#   'name': 'Populous',
#   'market_cap_usd': 54697100},
#  'STRAT': {'Ticker': 'STRAT',
#   'Price': 0.826122,
#   'Changes': -0.09,
#   'name': 'Stratis',
#   'market_cap_usd': 82054000},
#  'WAVES': {'Ticker': 'WAVES',
#   'Price': 2.44445,
#   'Changes': 1.27,
#   'name': 'Waves',
#   'market_cap_usd': 244445000},
#  'BTCP': {'Ticker': 'BTCP',
#   'Price': 1.73003,
#   'Changes': -0.18,
#   'name': 'Bitcoin Private',
#   'market_cap_usd': 35508000},
#  'MKR': {'Ticker': 'MKR',
#   'Price': 574.465,
#   'Changes': 2.37,
#   'name': 'Maker',
#   'market_cap_usd': 574465000},
#  'RHOC': {'Ticker': 'RHOC',
#   'Price': 0.152374,
#   'Changes': -3.89,
#   'name': 'RChain',
#   'market_cap_usd': 58946000},
#  'DCR': {'Ticker': 'DCR',
#   'Price': 27.4313,
#   'Changes': 2.16,
#   'name': 'Decred',
#   'market_cap_usd': 267912000},
#  'GNT': {'Ticker': 'GNT',
#   'Price': 0.071437,
#   'Changes': -2.39,
#   'name': 'Golem',
#   'market_cap_usd': 68838200},
#  'DOGE': {'Ticker': 'DOGE',
#   'Price': 0.00271699,
#   'Changes': 5.38,
#   'name': 'Dogecoin',
#   'market_cap_usd': 324576000},
#  'SNT': {'Ticker': 'SNT',
#   'Price': 0.0224258,
#   'Changes': -3.79,
#   'name': 'Status',
#   'market_cap_usd': 77828400},
#  'HSR': {'Ticker': 'HSR',
#   'Price': 2.13033,
#   'Changes': -7.3,
#   'name': 'Hshare',
#   'market_cap_usd': 92721900},
#  'IOST': {'Ticker': 'IOST',
#   'Price': 0.012916,
#   'Changes': 0.7,
#   'name': 'IOStoken',
#   'market_cap_usd': 155172000},
#  'WTC': {'Ticker': 'WTC',
#   'Price': 1.95039,
#   'Changes': -4.05,
#   'name': 'Waltonchain',
#   'market_cap_usd': 81296900},
#  'DGD': {'Ticker': 'DGD',
#   'Price': 36.7016,
#   'Changes': 1.72,
#   'name': 'DigixDAO',
#   'market_cap_usd': 73403300},
#  'LRC': {'Ticker': 'LRC',
#   'Price': 0.0592044,
#   'Changes': 4.13,
#   'name': 'Loopring',
#   'market_cap_usd': 49077700},
#  'DGB': {'Ticker': 'DGB',
#   'Price': 0.0110698,
#   'Changes': 2.56,
#   'name': 'DigiByte',
#   'market_cap_usd': 130426000},
#  'BAT': {'Ticker': 'BAT',
#   'Price': 0.354517,
#   'Changes': -1.16,
#   'name': 'Basic Attention Token',
#   'market_cap_usd': 447190000},
#  'AION': {'Ticker': 'AION',
#   'Price': 0.20355,
#   'Changes': 3.19,
#   'name': 'Aion',
#   'market_cap_usd': 63015400},
#  'REP': {'Ticker': 'REP',
#   'Price': 20.4049,
#   'Changes': 0.39,
#   'name': 'Augur',
#   'market_cap_usd': 224454000},
#  'XIN': {'Ticker': 'XIN',
#   'Price': 187.053,
#   'Changes': 5.71,
#   'name': 'Mixin',
#   'market_cap_usd': 82896100},
#  'KMD': {'Ticker': 'KMD',
#   'Price': 1.1096,
#   'Changes': -4.05,
#   'name': 'Komodo',
#   'market_cap_usd': 125647000},
#  'ARDR': {'Ticker': 'ARDR',
#   'Price': 0.073039,
#   'Changes': -0.66,
#   'name': 'Ardor',
#   'market_cap_usd': 72965900},
#  'ELF': {'Ticker': 'ELF',
#   'Price': 0.167023,
#   'Changes': 0.86,
#   'name': 'aelf',
#   'market_cap_usd': 58591700},
#  'MITH': {'Ticker': 'MITH',
#   'Price': 0.0705949,
#   'Changes': 1.94,
#   'name': 'Mithril',
#   'market_cap_usd': 34368400},
#  'NOTE': {'Ticker': 'NOTE',
#   'Price': 2.54893,
#   'Changes': 346.82,
#   'name': 'DNotes',
#   'market_cap_usd': 392180000},
#  'LOOM': {'Ticker': 'LOOM',
#   'Price': 0.0599882,
#   'Changes': -7.51,
#   'name': 'Loom Network',
#   'market_cap_usd': 47337100},
#  'NAS': {'Ticker': 'NAS',
#   'Price': 1.03582,
#   'Changes': 3.5,
#   'name': 'Nebulas',
#   'market_cap_usd': 47129600},
#  'ARK': {'Ticker': 'ARK',
#   'Price': 0.502392,
#   'Changes': 1.92,
#   'name': 'Ark',
#   'market_cap_usd': 56345200},
#  'KCS': {'Ticker': 'KCS',
#   'Price': 1.04323,
#   'Changes': 0.5,
#   'name': 'KuCoin Shares',
#   'market_cap_usd': 93535000},
#  'KNC': {'Ticker': 'KNC',
#   'Price': 0.323185,
#   'Changes': 17.39,
#   'name': 'Kyber Network',
#   'market_cap_usd': 53847400},
#  'GAS': {'Ticker': 'GAS',
#   'Price': 8.23719,
#   'Changes': 60.74,
#   'name': 'Gas',
#   'market_cap_usd': 83429300},
#  'PIVX': {'Ticker': 'PIVX',
#   'Price': 0.921548,
#   'Changes': 0.53,
#   'name': 'PIVX',
#   'market_cap_usd': 52326600},
#  'RDD': {'Ticker': 'RDD',
#   'Price': 0.00174459,
#   'Changes': 5.66,
#   'name': 'ReddCoin',
#   'market_cap_usd': 50259500},
#  'WICC': {'Ticker': 'WICC',
#   'Price': 0.259072,
#   'Changes': -5.66,
#   'name': 'WaykiChain',
#   'market_cap_usd': 48964600},
#  'SUB': {'Ticker': 'SUB',
#   'Price': 0.178403,
#   'Changes': -8.63,
#   'name': 'Substratum',
#   'market_cap_usd': 68332000},
#  'CTXC': {'Ticker': 'CTXC',
#   'Price': 0.33038,
#   'Changes': 1.82,
#   'name': 'Cortex',
#   'market_cap_usd': 49488400},
#  'MONA': {'Ticker': 'MONA',
#   'Price': 0.927014,
#   'Changes': -0.34,
#   'name': 'MonaCoin',
#   'market_cap_usd': 60932400},
#  'SYS': {'Ticker': 'SYS',
#   'Price': 0.0978142,
#   'Changes': 6.21,
#   'name': 'Syscoin',
#   'market_cap_usd': 52673200},
#  'CENNZ': {'Ticker': 'CENNZ',
#   'Price': 0.0382512,
#   'Changes': -3.26,
#   'name': 'Centrality',
#   'market_cap_usd': 30653800},
#  'QASH': {'Ticker': 'QASH',
#   'Price': 0.153433,
#   'Changes': -2.85,
#   'name': 'QASH',
#   'market_cap_usd': 53701600},
#  'NPXS': {'Ticker': 'NPXS',
#   'Price': 0.000610296,
#   'Changes': -3.12,
#   'name': 'Pundi X',
#   'market_cap_usd': 129396000},
#  'CNX': {'Ticker': 'CNX',
#   'Price': 1.57353,
#   'Changes': 6.15,
#   'name': 'Cryptonex',
#   'market_cap_usd': 87623900},
#  'DRGN': {'Ticker': 'DRGN',
#   'Price': 0.240251,
#   'Changes': 3.89,
#   'name': 'Dragonchain',
#   'market_cap_usd': 57281200},
#  'BNT': {'Ticker': 'BNT',
#   'Price': 0.6474,
#   'Changes': -11.33,
#   'name': 'Bancor',
#   'market_cap_usd': 40674500},
#  'GXS': {'Ticker': 'GXS',
#   'Price': 0.501727,
#   'Changes': 6.74,
#   'name': 'GXChain',
#   'market_cap_usd': 30103600},
#  'ETHOS': {'Ticker': 'ETHOS',
#   'Price': 1.24701,
#   'Changes': 5.1,
#   'name': 'Ethos',
#   'market_cap_usd': 96458600},
#  'STORM': {'Ticker': 'STORM',
#   'Price': 0.021722,
#   'Changes': 10.4,
#   'name': 'Storm',
#   'market_cap_usd': 97622200},
#  'VERI': {'Ticker': 'VERI',
#   'Price': 16.8482,
#   'Changes': -6.22,
#   'name': 'Veritaseum',
#   'market_cap_usd': 36217600},
#  'FUN': {'Ticker': 'FUN',
#   'Price': 0.0122788,
#   'Changes': 0.07,
#   'name': 'FunFair',
#   'market_cap_usd': 65886000},
#  'WAX': {'Ticker': 'WAX',
#   'Price': 0.0652349,
#   'Changes': -0.37,
#   'name': 'WAX',
#   'market_cap_usd': 61499100},
#  'NXT': {'Ticker': 'NXT',
#   'Price': 0.0302068,
#   'Changes': 5.63,
#   'name': 'Nxt',
#   'market_cap_usd': 30176600},
#  'DCN': {'Ticker': 'DCN',
#   'Price': 0.00014762,
#   'Changes': -0.72,
#   'name': 'Dentacoin',
#   'market_cap_usd': 48245500},
#  'FSN': {'Ticker': 'FSN',
#   'Price': 2.96575,
#   'Changes': -0.66,
#   'name': 'Fusion',
#   'market_cap_usd': 88036300},
#  'FCT': {'Ticker': 'FCT',
#   'Price': 9.70626,
#   'Changes': 0.81,
#   'name': 'Factom',
#   'market_cap_usd': 91843600},
#  'ELA': {'Ticker': 'ELA',
#   'Price': 3.39606,
#   'Changes': 4.12,
#   'name': 'Elastos',
#   'market_cap_usd': 52004700},
#  'SALT': {'Ticker': 'SALT',
#   'Price': 0.772418,
#   'Changes': -0.62,
#   'name': 'SALT',
#   'market_cap_usd': 63686400},
#  'GTO': {'Ticker': 'GTO',
#   'Price': 0.171439,
#   'Changes': 7.16,
#   'name': 'Gifto',
#   'market_cap_usd': 91511800},
#  'ETN': {'Ticker': 'ETN',
#   'Price': 0.00514456,
#   'Changes': 3.22,
#   'name': 'Electroneum',
#   'market_cap_usd': 48440400},
#  'ENG': {'Ticker': 'ENG',
#   'Price': 0.712045,
#   'Changes': 6.03,
#   'name': 'Enigma',
#   'market_cap_usd': 53286700},
#  'XZC': {'Ticker': 'XZC',
#   'Price': 6.90169,
#   'Changes': 7.78,
#   'name': 'ZCoin',
#   'market_cap_usd': 51530200},
#  'LINK': {'Ticker': 'LINK',
#   'Price': 0.647219,
#   'Changes': -3.95,
#   'name': 'ChainLink',
#   'market_cap_usd': 226527000},
#  'POLY': {'Ticker': 'POLY',
#   'Price': 0.118469,
#   'Changes': -14.03,
#   'name': 'Polymath',
#   'market_cap_usd': 41276000},
#  'POWR': {'Ticker': 'POWR',
#   'Price': 0.116454,
#   'Changes': 5.86,
#   'name': 'Power Ledger',
#   'market_cap_usd': 47146600}}

# %%
crypto_data_parsed['BTC']
# Out:
# {'Ticker': 'BTC',
#  'Price': 7154.05,
#  'Changes': 5.45,
#  'name': 'Bitcoin',
#  'market_cap_usd': 126597000000}

# %%
crypto_data_parsed['ETH']
# Out:
# {'Ticker': 'ETH',
#  'Price': 189.619,
#  'Changes': 0.2,
#  'name': 'Ethereum',
#  'market_cap_usd': 20106500000}

# %%
crypto_data_parsed['BTC']['Price']
# Out:
# 7154.05

# %%
crypto_data_parsed['BTC']['name']
# Out:
# 'Bitcoin'

# %% [markdown]
# We know how to obtain and parse data from the API but let us now figure out how to better format these imported data. Import the relevant packages stated below. [`pandas`](https://pandas.pydata.org/index.html) is a Python library that allows us to construct readable data structures like dataframes.

# %%
from pandas.io.json import json_normalize
import pandas as pd

# %% [markdown]
# Let us first create a sample readable dataframe.

# %%
json_normalize(crypto_data_parsed['BTC'])
# Out:
#    Changes    Price Ticker  market_cap_usd     name
# 0     5.45  7154.05    BTC    126597000000  Bitcoin

# %%
json_normalize(crypto_data_parsed['ETH'])
# Out:
#    Changes    Price Ticker  market_cap_usd      name
# 0      0.2  189.619    ETH     20106500000  Ethereum

# %% [markdown]
# We've observed that we can create a nice dataframe as shown above, albeit for single keys, 'BTC' or 'ETH' in this case. Let us create a function that allows us to create a single dataframe that stores the properties of every single cryptocurrency.

# %%
# Examine the list of keys available from the imported data
list(crypto_data_parsed.keys())
# Out:
# ['BTC',
#  'ETH',
#  'XRP',
#  'BCH',
#  'EOS',
#  'LTC',
#  'ADA',
#  'XLM',
#  'MIOTA',
#  'TRX',
#  'NEO',
#  'DASH',
#  'XMR',
#  'XEM',
#  'VEN',
#  'ETC',
#  'USDT',
#  'QTUM',
#  'OMG',
#  'ICX',
#  'BNB',
#  'LSK',
#  'BTG',
#  'NANO',
#  'BCN',
#  'XVG',
#  'ZEC',
#  'ONT',
#  'AE',
#  'STEEM',
#  'ZIL',
#  'WAN',
#  'SC',
#  'BTS',
#  'BTM',
#  'ZRX',
#  'BCD',
#  'PPT',
#  'STRAT',
#  'WAVES',
#  'BTCP',
#  'MKR',
#  'RHOC',
#  'DCR',
#  'GNT',
#  'DOGE',
#  'SNT',
#  'HSR',
#  'IOST',
#  'WTC',
#  'DGD',
#  'LRC',
#  'DGB',
#  'BAT',
#  'AION',
#  'REP',
#  'XIN',
#  'KMD',
#  'ARDR',
#  'ELF',
#  'MITH',
#  'NOTE',
#  'LOOM',
#  'NAS',
#  'ARK',
#  'KCS',
#  'KNC',
#  'GAS',
#  'PIVX',
#  'RDD',
#  'WICC',
#  'SUB',
#  'CTXC',
#  'MONA',
#  'SYS',
#  'CENNZ',
#  'QASH',
#  'NPXS',
#  'CNX',
#  'DRGN',
#  'BNT',
#  'GXS',
#  'ETHOS',
#  'STORM',
#  'VERI',
#  'FUN',
#  'WAX',
#  'NXT',
#  'DCN',
#  'FSN',
#  'FCT',
#  'ELA',
#  'SALT',
#  'GTO',
#  'ETN',
#  'ENG',
#  'XZC',
#  'LINK',
#  'POLY',
#  'POWR']

# %%
def get_finance_df(url):
    # Parse JSON data from API
    json_data = get_jsonparsed_data(url)
    # Get a list containing dataframes
    frames = [json_normalize(json_data[i]) for i in list(json_data.keys())]
    # Combine the isolated dataframes obtained above
    combi_frames = pd.concat(frames, ignore_index=True)
    return combi_frames

# %%
crypto_df = get_finance_df(crypto_url)
crypto_df
# Out:
#     Changes        Price Ticker  market_cap_usd              name
# 0      5.45  7154.050000    BTC    126597000000           Bitcoin
# 1      0.20   189.619000    ETH     20106500000          Ethereum
# 2     -0.24     0.312575    XRP     13169800000            Ripple
# 3     10.14   353.042000    BCH      6276350000      Bitcoin Cash
# 4      1.86     5.416980    EOS      4936450000               EOS
# 5      1.60    87.638000    LTC      5410550000          Litecoin
# 6      0.06     0.070841    ADA      1836690000           Cardano
# 7      1.77     0.099908    XLM      1916700000           Stellar
# 8     -0.01     0.301348  MIOTA       837606000              IOTA
# 9     -2.25     0.024172    TRX      1611860000              TRON
# 10    -1.11     9.472680    NEO       615724000               NEO
# 11     2.00   121.718000   DASH      1071480000              Dash
# 12     2.69    74.801600    XMR      1269830000            Monero
# 13    -0.22     0.056525    XEM       508722000               NEM
# 14   -13.36     1.734920    VEN       962093000           VeChain
# 15    -0.31     5.896010    ETC       650903000  Ethereum Classic
# 16    -0.35     1.000380   USDT      2779160000            Tether
# 17    -1.96     2.455680   QTUM       235043000              Qtum
# 18    -2.73     1.692120    OMG       237312000           OmiseGO
# 19    -3.03     0.329284    ICX       155885000              ICON
# 20     2.16    20.886700    BNB      2948680000      Binance Coin
# 21     0.05     1.905700    LSK       222705000              Lisk
# 22     5.64    22.179900    BTG       388457000      Bitcoin Gold
# 23     5.03     1.674000   NANO       223057000              Nano
# 24     3.19     0.001002    BCN       184506000          Bytecoin
# 25    -1.52     0.007298    XVG       116839000             Verge
# 26     1.12    61.475000    ZEC       400545000             Zcash
# 27    -1.04     1.165930    ONT       577141000          Ontology
# 28    -1.79     0.462911     AE       122164000         Aeternity
# 29    -1.45     0.316151  STEEM       101719000             Steem
# ..      ...          ...    ...             ...               ...
# 70    -5.66     0.259072   WICC        48964600        WaykiChain
# 71    -8.63     0.178403    SUB        68332000        Substratum
# 72     1.82     0.330380   CTXC        49488400            Cortex
# 73    -0.34     0.927014   MONA        60932400          MonaCoin
# 74     6.21     0.097814    SYS        52673200           Syscoin
# 75    -3.26     0.038251  CENNZ        30653800        Centrality
# 76    -2.85     0.153433   QASH        53701600              QASH
# 77    -3.12     0.000610   NPXS       129396000           Pundi X
# 78     6.15     1.573530    CNX        87623900         Cryptonex
# 79     3.89     0.240251   DRGN        57281200       Dragonchain
# 80   -11.33     0.647400    BNT        40674500            Bancor
# 81     6.74     0.501727    GXS        30103600           GXChain
# 82     5.10     1.247010  ETHOS        96458600             Ethos
# 83    10.40     0.021722  STORM        97622200             Storm
# 84    -6.22    16.848200   VERI        36217600        Veritaseum
# 85     0.07     0.012279    FUN        65886000           FunFair
# 86    -0.37     0.065235    WAX        61499100               WAX
# 87     5.63     0.030207    NXT        30176600               Nxt
# 88    -0.72     0.000148    DCN        48245500         Dentacoin
# 89    -0.66     2.965750    FSN        88036300            Fusion
# 90     0.81     9.706260    FCT        91843600            Factom
# 91     4.12     3.396060    ELA        52004700           Elastos
# 92    -0.62     0.772418   SALT        63686400              SALT
# 93     7.16     0.171439    GTO        91511800             Gifto
# 94     3.22     0.005145    ETN        48440400       Electroneum
# 95     6.03     0.712045    ENG        53286700            Enigma
# 96     7.78     6.901690    XZC        51530200             ZCoin
# 97    -3.95     0.647219   LINK       226527000         ChainLink
# 98   -14.03     0.118469   POLY        41276000          Polymath
# 99     5.86     0.116454   POWR        47146600      Power Ledger
#
# [100 rows x 5 columns]

# %% [markdown]
# From this collated set of data, you can do your own set of analyses you deem fit.

# %%
crypto_df.nlargest(3, 'market_cap_usd')
# Out:
#    Changes        Price Ticker  market_cap_usd      name
# 0     5.45  7154.050000    BTC    126597000000   Bitcoin
# 1     0.20   189.619000    ETH     20106500000  Ethereum
# 2    -0.24     0.312575    XRP     13169800000    Ripple

# %% [markdown]
# Now that you have an idea of how to obtain data from such an API, you can try retrieving data on your own from different endpoints. You can try the following for starters:
# + Major Indexes (https://financialmodelingprep.com/api/majors-indexes?datatype=json)
# + Forex (FX) (https://financialmodelingprep.com/api/forex?datatype=json)

# %% [markdown]
# ## Major Indexes

# %%
maj_index_url = 'https://financialmodelingprep.com/api/majors-indexes?datatype=json'

# %%
maj_index_df = get_finance_df(maj_index_url)
maj_index_df
# Out:
#      Changes                              Name     Price   Ticker  \
# 0   178.6480                         Dow Jones  25942.40     .DJI
# 1    36.0000                            Nasdaq   7917.00    .IXIC
# 2    18.2998                           S&P 500   2881.40     .INX
# 3   -26.0601                            CAC 40   5327.44  %5EFCHI
# 4     5.7700                Russell 1000 Index   1597.05   %5ERUI
# 5     2.9900                Russell 2000 Index   1572.99   %5ERUT
# 6    16.9900    NYSE Arca Technology 100 Index   3346.71   %5EPSE
# 7     0.6709  Dow Jones Transportation Average  10602.20   %5EDJT
# 8    24.3799             NASDAQ Computer Index   4812.96  %5EIXCO
# 9    11.5601             S&P 400 Mid Cap Index   1933.43   %5EMID
# 10   30.4898                  NASDAQ 100 Index   7586.53   %5ENDX
# 11   86.0498              NYSE Composite Index  12788.10   %5ENYA
# 12    7.1900                     S&P 100 Index   1275.10   %5EOEX
# 13    9.8001          PHLX Semiconductor Index   1478.87   %5ESOX
# 14   -0.8300            PHLX Gold/Silver Index     67.29   %5EXAU
# 15   29.0598     NYSE American Composite Index   2576.90   %5EXAX
# 16    4.6299      NYSE Arca Major Market Index   2612.18   %5EXMI
#
#              updated_at
# 0   2019-05-12 13:06:12
# 1   2019-05-10 16:06:56
# 2   2019-05-12 13:06:23
# 3   2019-05-12 13:06:29
# 4   2019-05-10 21:07:14
# 5   2019-05-10 21:07:20
# 6   2019-05-10 21:07:26
# 7   2019-05-12 04:07:23
# 8   2019-05-11 00:07:29
# 9   2019-05-11 14:07:23
# 10  2019-05-11 14:07:29
# 11  2019-05-11 11:07:06
# 12  2019-05-11 11:07:12
# 13  2019-05-11 11:07:17
# 14  2019-05-11 11:07:23
# 15  2019-05-11 11:07:29
# 16  2019-05-10 09:07:00

# %%
# Sort results by 'Changes' column in descending manner
maj_index_df.sort_values(by='Changes', ascending=False)
# Out:
#      Changes                              Name     Price   Ticker  \
# 0   178.6480                         Dow Jones  25942.40     .DJI
# 11   86.0498              NYSE Composite Index  12788.10   %5ENYA
# 1    36.0000                            Nasdaq   7917.00    .IXIC
# 10   30.4898                  NASDAQ 100 Index   7586.53   %5ENDX
# 15   29.0598     NYSE American Composite Index   2576.90   %5EXAX
# 8    24.3799             NASDAQ Computer Index   4812.96  %5EIXCO
# 2    18.2998                           S&P 500   2881.40     .INX
# 6    16.9900    NYSE Arca Technology 100 Index   3346.71   %5EPSE
# 9    11.5601             S&P 400 Mid Cap Index   1933.43   %5EMID
# 13    9.8001          PHLX Semiconductor Index   1478.87   %5ESOX
# 12    7.1900                     S&P 100 Index   1275.10   %5EOEX
# 4     5.7700                Russell 1000 Index   1597.05   %5ERUI
# 16    4.6299      NYSE Arca Major Market Index   2612.18   %5EXMI
# 5     2.9900                Russell 2000 Index   1572.99   %5ERUT
# 7     0.6709  Dow Jones Transportation Average  10602.20   %5EDJT
# 14   -0.8300            PHLX Gold/Silver Index     67.29   %5EXAU
# 3   -26.0601                            CAC 40   5327.44  %5EFCHI
#
#              updated_at
# 0   2019-05-12 13:06:12
# 11  2019-05-11 11:07:06
# 1   2019-05-10 16:06:56
# 10  2019-05-11 14:07:29
# 15  2019-05-11 11:07:29
# 8   2019-05-11 00:07:29
# 2   2019-05-12 13:06:23
# 6   2019-05-10 21:07:26
# 9   2019-05-11 14:07:23
# 13  2019-05-11 11:07:17
# 12  2019-05-11 11:07:12
# 4   2019-05-10 21:07:14
# 16  2019-05-10 09:07:00
# 5   2019-05-10 21:07:20
# 7   2019-05-12 04:07:23
# 14  2019-05-11 11:07:23
# 3   2019-05-12 13:06:29

# %% [markdown]
# ## Stock Historical Prices (with change and volume)

# %%
forex_url = 'https://financialmodelingprep.com/api/forex?datatype=json'

# %%
forex_df = get_finance_df(forex_url)
forex_df
# Out:
#         Changes                          Name       Price   Ticker
# 0 -1.975800e-16                          Euro    1.123820  EUR/USD
# 1  0.000000e+00                  Japanese Yen  109.958000  USD/JPY
# 2  3.843850e-06                 British Pound    1.300780  GBP/USD
# 3 -2.196530e-16                  Swiss Francs    1.010890  USD/CHF
# 4  0.000000e+00          Euro / British Pound    0.863965  EUR/GBP
# 5  0.000000e+00           Euro / Japanese Yen  123.577000  EUR/JPY
# 6  0.000000e+00           Euro / Swiss Francs    1.136080  EUR/CHF
# 7 -3.724530e-06            Dollar / Canadians    1.342450  USD/CAD
# 8  0.000000e+00                    Autralians    0.700140  AUD/USD
# 9 -3.495700e-06  British Pound / Japanese Yen  143.033000  GBP/JPY

# %% [markdown]
# <center> <h1>~ End of section ~</h1> </center>
